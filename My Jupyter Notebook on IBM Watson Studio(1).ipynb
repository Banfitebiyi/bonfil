# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # Banfitebiyi GAMBOGOU
# Microbiologist, data scientist and data analyst

# %% [markdown]
# *I am interested in Data Science because it allows to explore and analyze raw data to transform them into valuable information to solve problems. this helps to improve products by evaluating and understanding their state of health and providing product-related decisions (mainly through experimentation)*

# %% [markdown]
# Du code informatique :
#     def ma fonction f(x, y)
#     return x + y

# %%
x = 10
y = 5
print(x + y)
# Out:
# 15

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

temps=[0, 2, 4, 6, 8, 12, 16, 18, 22]
bactérie=[0.1, 0.1, 0.15, 1, 2, 2, 2, 1, 0.5]

plt.plot(temps, bactérie, ls='-', color="blue")

plt.xlabel("Temps (h)")
plt.ylabel("nombre de colonie (10^5 UFC/mL)")
plt.title("Courbe de croissance bactérienne en fonction du temps")
# Out:
# Text(0.5, 1.0, 'Courbe de croissance bactérienne en fonction du temps')
